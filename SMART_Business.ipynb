# %%
# !pip install pandas

# %%
# !pip install tabulate

# %%
# SECTION 1  WATERFALL
df_waterfall = pd.DataFrame([
    ["Project Initiation", "Define Scope", "Identify modules and constraints", "PMO", "Day 1", "Day 3", "High"],
    ["Project Initiation", "Stakeholder Mapping", "Determine owners", "PMO", "Day 3", "Day 4", "Medium"],
    ["Requirements Analysis", "CRM Requirements", "Customer data structure, UI rules", "Sales + CRM Team", "Day 4", "Day 7", "High"],
    ["Requirements Analysis", "Contract Workflow", "Approval chain, digital signature process", "Legal + Sales", "Day 4", "Day 8", "High"],
    ["Requirements Analysis", "Delivery Process", "Delivery note rules, QR code", "Logistics", "Day 5", "Day 9", "High"],
    ["Requirements Analysis", "Invoicing Model", "Automated invoicing, payment cycles", "Finance", "Day 5", "Day 9", "High"],
    ["Requirements Analysis", "Inventory Rules", "Stock logic, safety levels", "Production + Warehouse", "Day 6", "Day 10", "High"],
    ["Requirements Analysis", "Ticketing Process", "SLA rules, routing logic", "Support", "Day 6", "Day 10", "Medium"],
    ["System Design", "Architecture Diagram", "CRM + Inventory + Finance integration", "IT + PMO", "Day 10", "Day 13", "High"],
    ["System Design", "Data Model", "Entities, relationships", "Data Team", "Day 10", "Day 14", "High"],
    ["System Design", "Workflow Design", "Contract, delivery, invoicing workflows", "PMO + IT", "Day 11", "Day 15", "High"],
    ["System Design", "Power BI KPI Definition", "Dashboard KPIs", "Management + Data Team", "Day 11", "Day 15", "Medium"],
], columns=["Phase", "Task", "Subtask", "Department", "Start Date", "Due Date", "Priority"])

display(df_waterfall)
# Out:
#                     Phase                     Task  \
# 0      Project Initiation             Define Scope
# 1      Project Initiation      Stakeholder Mapping
# 2   Requirements Analysis         CRM Requirements
# 3   Requirements Analysis        Contract Workflow
# 4   Requirements Analysis         Delivery Process
# 5   Requirements Analysis          Invoicing Model
# 6   Requirements Analysis          Inventory Rules
# 7   Requirements Analysis        Ticketing Process
# 8           System Design     Architecture Diagram
# 9           System Design               Data Model
# 10          System Design          Workflow Design
# 11          System Design  Power BI KPI Definition
#
#                                       Subtask              Department  \
# 0            Identify modules and constraints                     PMO
# 1                            Determine owners                     PMO
# 2           Customer data structure, UI rules        Sales + CRM Team
# ...

# %%
# SECTION 2  AGILE
df_agile = pd.DataFrame([
    ["Sprint 1", "CRM UI Build", "Contact forms, customer screens", "CRM Dev + UI/UX", "Day 15", "Day 20", "High"],
    ["Sprint 1", "Data Migration (Phase 1)", "Clean & import customer records", "Data Team", "Day 15", "Day 20", "High"],
    ["Sprint 2", "Contract Module", "OCR + approval workflow", "Legal + CRM Dev", "Day 20", "Day 25", "High"],
    ["Sprint 2", "Contract e-Signature", "Integration + testing", "IT + Vendor", "Day 20", "Day 25", "Medium"],
    ["Sprint 3", "Delivery Module", "Digital delivery note (QR)", "Logistics + Dev", "Day 25", "Day 30", "High"],
    ["Sprint 3", "Delivery Confirmation", "Customer sign-off flow", "CRM Dev", "Day 25", "Day 30", "Medium"],
    ["Sprint 4", "Invoicing Module", "Auto invoice + email", "Finance + CRM Dev", "Day 30", "Day 34", "High"],
    ["Sprint 4", "Payment Tracking", "Overdue alerts", "Finance", "Day 30", "Day 34", "Medium"],
    ["Sprint 5", "Inventory Module", "Stock update automation", "Warehouse + Integration Dev", "Day 34", "Day 38", "High"],
    ["Sprint 5", "Warehouse Mapping", "Bin/zone mapping", "Warehouse Team", "Day 34", "Day 38", "Medium"],
    ["Sprint 6", "Ticketing System", "Create SLA rules", "Support", "Day 38", "Day 42", "Medium"],
    ["Sprint 6", "Ticket Routing", "Auto-assign logic", "Dev Team", "Day 38", "Day 42", "Low"],
    ["Sprint 7", "Power BI Dashboards", "Sales/Delivery KPIs", "Data Team", "Day 42", "Day 46", "High"],
    ["Sprint 7", "Report Publishing", "Workspace + roles", "IT + Data", "Day 42", "Day 46", "Medium"],
    ["Sprint 8", "User Acceptance Testing", "Scenario-based testing", "All Departments", "Day 46", "Day 50", "High"],
    ["Sprint 8", "Fixes & Optimization", "UI + performance", "Dev Team", "Day 46", "Day 50", "Medium"],
], columns=["Sprint", "Feature", "Subtask", "Department", "Start Date", "Due Date", "Priority"])

display(df_agile)
# Out:
#       Sprint                   Feature                          Subtask  \
# 0   Sprint 1              CRM UI Build  Contact forms, customer screens
# 1   Sprint 1  Data Migration (Phase 1)  Clean & import customer records
# 2   Sprint 2           Contract Module          OCR + approval workflow
# 3   Sprint 2      Contract e-Signature            Integration + testing
# 4   Sprint 3           Delivery Module       Digital delivery note (QR)
# 5   Sprint 3     Delivery Confirmation           Customer sign-off flow
# 6   Sprint 4          Invoicing Module             Auto invoice + email
# 7   Sprint 4          Payment Tracking                   Overdue alerts
# 8   Sprint 5          Inventory Module          Stock update automation
# 9   Sprint 5         Warehouse Mapping                 Bin/zone mapping
# 10  Sprint 6          Ticketing System                 Create SLA rules
# 11  Sprint 6            Ticket Routing                Auto-assign logic
# ...

# %%
# SECTION 3 RACI MATRIX
#R = Responsible 
#A = Accountable 
#C = Consulted 
#I = Informed
df_raci = pd.DataFrame([
    ["PMO", "A", "A", "A", "A", "A", "A", "A"],
    ["CRM Dev", "R", "R", "R", "R", "C", "R", "C"],
    ["UI/UX", "R", "C", "C", "C", "C", "C", "C"],
    ["Sales", "R", "C", "I", "I", "I", "I", "C"],
    ["Legal", "C", "R", "I", "I", "I", "I", "I"],
    ["Finance", "I", "I", "I", "R", "C", "I", "C"],
    ["Logistics", "I", "I", "R", "I", "I", "I", "I"],
    ["Warehouse", "I", "I", "C", "I", "R", "I", "I"],
    ["Data Team", "C", "I", "I", "C", "I", "C", "R"],
    ["IT / Integration", "C", "C", "C", "C", "R", "C", "C"],
    ["Support", "I", "I", "I", "I", "I", "R", "I"],
    ["Management", "I", "A", "A", "A", "A", "A", "A"],
], columns=["Department", "CRM", "Contracts", "Delivery", "Invoicing", "Inventory", "Ticketing", "Power BI"])

display(df_raci)
# Out:
#           Department CRM Contracts Delivery Invoicing Inventory Ticketing  \
# 0                PMO   A         A        A         A         A         A
# 1            CRM Dev   R         R        R         R         C         R
# 2              UI/UX   R         C        C         C         C         C
# 3              Sales   R         C        I         I         I         I
# 4              Legal   C         R        I         I         I         I
# 5            Finance   I         I        I         R         C         I
# 6          Logistics   I         I        R         I         I         I
# 7          Warehouse   I         I        C         I         R         I
# 8          Data Team   C         I        I         C         I         C
# 9   IT / Integration   C         C        C         C         R         C
# 10           Support   I         I        I         I         I         R
# 11        Management   I         A        A         A         A         A
#
# ...

# %%
def highlight_priority(val):
    """
    Color High / Medium / Low priorities:
    - High   -> red
    - Medium -> yellow
    - Low    -> green
    """
    if val == "High":
        return "background-color: #ff4d4d; color: white;"   
    elif val == "Medium":
        return "background-color: #ffd633; color: black;"   
    elif val == "Low":
        return "background-color: #5cd65c; color: black;"   
    return ""


print("                                                      WATERFALL PLAN ")
display(df_waterfall.style.map(highlight_priority, subset=["Priority"]))

print("                                              AGILE SPRINT PLAN ")
display(df_agile.style.map(highlight_priority, subset=["Priority"]))

print("RACI MATRIX" " (R = Responsible , A = Accountable , C = Consulted , I = Informed )")
display(df_raci)
# Out:
#                                                       WATERFALL PLAN
# <style type="text/css">
# #T_23856_row0_col6, #T_23856_row2_col6, #T_23856_row3_col6, #T_23856_row4_col6, #T_23856_row5_col6, #T_23856_row6_col6, #T_23856_row8_col6, #T_23856_row9_col6, #T_23856_row10_col6 {
#   background-color: #ff4d4d;
#   color: white;
# }
# #T_23856_row1_col6, #T_23856_row7_col6, #T_23856_row11_col6 {
#   background-color: #ffd633;
#   color: black;
# }
# </style>
# <table id="T_23856">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_23856_level0_col0" class="col_heading level0 col0" >Phase</th>
#       <th id="T_23856_level0_col1" class="col_heading level0 col1" >Task</th>
#       <th id="T_23856_level0_col2" class="col_heading level0 col2" >Subtask</th>
#       <th id="T_23856_level0_col3" class="col_heading level0 col3" >Department</th>
#       <th id="T_23856_level0_col4" class="col_heading level0 col4" >Start Date</th>
# ...

# %%
## 5. Stakeholder Analysis

import pandas as pd
from IPython.display import display


# STAKEHOLDER RISK 

stakeholder_risk_data = [
    # Stakeholder Group, Department, Related Modules, Influence, Interest, Risk Level, Risk Description, Mitigation Owner, Mitigation Action

    ["Project Manager (IT)", "IT",
     "Overall CRM, BI, System Delivery",
     "High", "High", "Medium",
     "Overload can delay decisions and coordination.",
     "PMO",
     "Hold weekly syncs, balance workload, and clarify priorities."],

    ["IT Department Staff", "IT",
     "Integrations, Architecture, Security",
     "High", "Medium", "High",
     "Technical delays or bugs can block key modules.",
     "PM + IT Lead",
     "Define clear integration scope, add buffer time, review technical risks weekly."],

    ["External Consultants", "Consultants",
     "CRM UI, Workflows, BI components",
     "Medium", "Medium", "Medium",
     "Dependency on consultants may cause delays or misalignment.",
     "PM",
     "Clarify responsibilities in contract, run weekly progress reviews."],

    ["Sales Department", "Sales",
     "CRM, Customer Data, Contracts",
     "High", "High", "High",
     "Resistance to new CRM or low adoption.",
     "Business Analyst",
     "Involve key sales reps in requirements & UAT, deliver tailored CRM training."],

    ["Design Department", "Design",
     "UI/UX, CRM Screens",
     "Medium", "Medium", "Medium",
     "UI expectations may not match implemented screens.",
     "UX Lead",
     "Run UI/UX review sessions before development and after each sprint demo."],

    ["Financial Department", "Finance",
     "Invoicing, Payments, Finance KPIs",
     "High", "Medium", "High",
     "Incorrect invoicing rules may impact cash flow.",
     "Finance Lead",
     "Validate invoicing logic early, run parallel invoicing during transition."],

    ["Company Management (Sponsors)", "Management",
     "Budget, High-level KPIs, Overall Results",
     "High", "Low", "Medium",
     "Lack of visible results may reduce sponsor support.",
     "PMO",
     "Provide executive dashboards and quick wins in early sprints."]
]

df_stakeholder_risk = pd.DataFrame(
    stakeholder_risk_data,
    columns=[
        "Stakeholder Group", "Department", "Related Modules",
        "Influence", "Interest", "Risk Level",
        "Risk Description", "Mitigation Owner", "Mitigation Action"
    ]
)


# STAKEHOLDER COMMUNICATION PLAN


stakeholder_comm_data = [
    ["Project Manager (IT)", "Executor / Coordinator",
     "Daily progress, risks, blockers.",
     "Daily stand-up + chat (Teams/Slack)", "Daily",
     "PM",
     "Escalate unresolved blockers to Company Management (Sponsors)."],

    ["IT Department Staff", "Technical Owners",
     "Integration scope, architecture changes, incidents.",
     "Technical meetings + Jira", "Weekly",
     "PM + IT Lead",
     "Escalate technical blockers to CIO"],

    ["External Consultants", "External Executors",
     "UI components, workflow tasks, BI modules.",
     "Email + MS Teams + Jira", "Weekly",
     "PM",
     "Escalate delays to Consulting Partner"],

    ["Sales Department", "Key Users",
     "CRM features, customer data rules, release notes.",
     "Workshops + Email", "Bi-weekly",
     "Business Analyst",
     "Escalate adoption issues to Sales Director"],

    ["Design Department", "UI/UX Contributors",
     "Screen layouts, UX guidelines, visual consistency.",
     "UX review meetings", "Weekly",
     "UX Lead",
     "Escalate inconsistencies to PMO"],

    ["Financial Department", "Process Owners",
     "Invoicing rules, payment tracking, testing updates.",
     "Workshops + Email", "Weekly",
     "Finance Lead",
     "Escalate blocking issues to CFO"],

    ["Company Management (Sponsors)", "Sponsors",
     "High-level KPIs, budget usage, delivery progress.",
     "Steering meeting + BI Dashboard", "Monthly",
     "PM",
     "Escalate delays or scope issues to CEO"],
]

df_stakeholder_comm = pd.DataFrame(
    stakeholder_comm_data,
    columns=[
        "Stakeholder Group", "Role in Project", "Information Needs",
        "Communication Channel", "Frequency", "Responsible", "Escalation Path"
    ]
)



risk_style_map = {
    "High": "background-color: #ff4d4d; color: white;",
    "Medium": "background-color: #ffd633; color: black;",
    "Low": "background-color: #5cd65c; color: black;",
}

influence_interest_style_map = {
    "High": "background-color: #cce5ff; color: black;",
    "Medium": "background-color: #e6e6e6; color: black;",
    "Low": "background-color: #ffffff; color: black;",
}

def risk_style(val):
    return risk_style_map.get(val, "")

def influence_interest_style(val):
    return influence_interest_style_map.get(val, "")



display(
    df_stakeholder_risk.style
        .map(risk_style, subset=["Risk Level"])
        .map(influence_interest_style, subset=["Influence"])
        .map(influence_interest_style, subset=["Interest"])
)

display(df_stakeholder_comm)
# Out:
# <style type="text/css">
# #T_55ddf_row0_col3, #T_55ddf_row0_col4, #T_55ddf_row1_col3, #T_55ddf_row3_col3, #T_55ddf_row3_col4, #T_55ddf_row5_col3, #T_55ddf_row6_col3 {
#   background-color: #cce5ff;
#   color: black;
# }
# #T_55ddf_row0_col5, #T_55ddf_row2_col5, #T_55ddf_row4_col5, #T_55ddf_row6_col5 {
#   background-color: #ffd633;
#   color: black;
# }
# #T_55ddf_row1_col4, #T_55ddf_row2_col3, #T_55ddf_row2_col4, #T_55ddf_row4_col3, #T_55ddf_row4_col4, #T_55ddf_row5_col4 {
#   background-color: #e6e6e6;
#   color: black;
# }
# #T_55ddf_row1_col5, #T_55ddf_row3_col5, #T_55ddf_row5_col5 {
#   background-color: #ff4d4d;
#   color: white;
# }
# #T_55ddf_row6_col4 {
#   background-color: #ffffff;
#   color: black;
# }
# </style>
# <table id="T_55ddf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_55ddf_level0_col0" class="col_heading level0 col0" >Stakeholder Group</th>
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# ===========================
# GANTT DATA (Waterfall + Agile)
# ===========================

tasks = [
    # Waterfall phases
    ["Initiation",            "2025-01-01", "2025-01-05", "Waterfall", 100],
    ["Requirements Analysis", "2025-01-06", "2025-01-15", "Waterfall", 100],
    ["System Design",         "2025-01-16", "2025-01-22", "Waterfall", 100],

    # Agile sprints
    ["Sprint 1 - CRM Base",           "2025-01-23", "2025-01-28", "Agile", 100],
    ["Sprint 2 - Contract Workflow",  "2025-01-29", "2025-02-03", "Agile", 90],
    ["Sprint 3 - Delivery Module",    "2025-02-04", "2025-02-09", "Agile", 80],
    ["Sprint 4 - Invoicing Module",   "2025-02-10", "2025-02-15", "Agile", 75],
    ["Sprint 5 - Inventory System",   "2025-02-16", "2025-02-21", "Agile", 70],
    ["Sprint 6 - Ticketing System",   "2025-02-22", "2025-02-27", "Agile", 60],
    ["Sprint 7 - BI Dashboards",      "2025-02-28", "2025-03-04", "Agile", 40],
    ["Sprint 8 - Final Integration",  "2025-03-05", "2025-03-10", "Agile", 30],
]

df = pd.DataFrame(tasks, columns=["Task", "Start", "End", "Phase", "% Complete"])

# Tarihleri datetime'a çevir
df["Start"] = pd.to_datetime(df["Start"])
df["End"]   = pd.to_datetime(df["End"])

# Süre (gün)
df["Duration"] = (df["End"] - df["Start"]).dt.days

# Sıra bozulmasın diye index kullanacağız
y_pos = list(range(len(df)))

# ===========================
# RENK FONKSİYONLARI
# ===========================

def phase_color(phase):
    """Waterfall / Agile için temel renk"""
    if phase == "Waterfall":
        return "#cce5ff"   # açık mavi
    else:
        return "#ccffcc"   # açık yeşil

def progress_edge_color(pct):
    """Tamamlama yüzdesine göre kenar rengi (opsiyonel)"""
    if pct >= 90: 
        return "#2eb82e"   # yeşil ton
    if pct >= 70: 
        return "#e6ac00"   # sarımsı
    if pct >= 40: 
        return "#ff8000"   # turuncu
    return "#ff3333"       # kırmızı

# ===========================
# GANTT ÇİZİMİ
# ===========================

fig, ax = plt.subplots(figsize=(14, 8))

for i, row in df.iterrows():
    start = row["Start"]
    duration = row["Duration"]
    phase = row["Phase"]
    pct = row["% Complete"]
    
    # Bar
    ax.barh(
        y=i,
        width=duration,
        left=start,
        color=phase_color(phase),
        edgecolor=progress_edge_color(pct)
    )
    
    # % Completion yazısı
    ax.text(
        start + pd.Timedelta(days=duration/2),
        i,
        f'{pct}%',
        ha='center',
        va='center',
        fontsize=8
    )

# Görev isimleri (yukarıdan aşağı sıralı)
ax.set_yticks(y_pos)
ax.set_yticklabels(df["Task"])

# İlk task en üstte gözüksün diye:
ax.invert_yaxis()

ax.set_xlabel("Timeline")
ax.set_ylabel("Tasks")
ax.set_title("Gantt Chart (Waterfall + Agile)", fontsize=14, weight="bold")
ax.grid(axis='x', linestyle='--', alpha=0.3)

# ===========================
# WATERFALL / AGILE AYRIM ÇİZGİSİ
# ===========================

# Waterfall'un bittiği tarih = son Waterfall task'inin bitişi
waterfall_end = df[df["Phase"] == "Waterfall"]["End"].max()

# Projenin en erken ve en geç tarihleri
project_start = df["Start"].min()
project_end   = df["End"].max()

# Dikey çizgi
ax.axvline(waterfall_end, color="black", linestyle="--", linewidth=1)

# Faz başlıklarını üstte yazalım
# y ekseninin üstünden biraz yukarıya yazmak için:
y_top = -0.8  # -0.5 üstü, biraz daha yukarı

# Waterfall yazısı (solda)
mid_waterfall = project_start + (waterfall_end - project_start) / 2
ax.text(
    mid_waterfall,
    y_top,
    "Waterfall",
    ha='center',
    va='center',
    fontsize=11,
    fontweight='bold'
)

# Agile yazısı (sağda)
mid_agile = waterfall_end + (project_end - waterfall_end) / 2
ax.text(
    mid_agile,
    y_top,
    "Agile",
    ha='center',
    va='center',
    fontsize=11,
    fontweight='bold'
)

plt.tight_layout()
plt.show()

# %%
#VISUALIZATION CHARTS

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# SPRINTS__________-----------------

# SPRINT RELATED TO WORKLOAD
sprint_labels = [f"Sprint {i}" for i in range(1, 9)]
sprint_effort = [12, 12, 12, 12, 12, 12, 14, 14]  

fig, ax = plt.subplots(figsize=(6, 6))
ax.pie(
    sprint_effort,
    labels=sprint_labels,
    autopct='%1.1f%%',
    startangle=90
)
ax.set_title("Sprint Effort Distribution")
ax.axis('equal') 
plt.show()


# Module PIE CHARTS ---------------------
module_labels = [
    "CRM UI & Customer Data",
    "Contract Workflow",
    "Delivery Module",
    "Invoicing",
    "Inventory",
    "Ticketing",
    "Power BI & Reporting"
]

module_complexity = [18, 15, 12, 15, 15, 10, 15] 
fig, ax = plt.subplots(figsize=(6, 6))
ax.pie(
    module_complexity,
    labels=module_labels,
    autopct='%1.1f%%',
    startangle=90
)
ax.set_title("Module Complexity / Effort Distribution")
ax.axis('equal')
plt.show()


#-------------------------RACI pie charts

# Departments
departments = [
    "PMO",
    "CRM Dev",
    "UI/UX",
    "Sales",
    "Legal",
    "Finance",
    "Logistics",
    "Warehouse",
    "Data Team",
    "IT / Integration",
    "Support",
    "Management"
]

# Ex
responsibility_count = [5, 6, 3, 4, 3, 4, 2, 2, 3, 4, 2, 5]

fig, ax = plt.subplots(figsize=(10, 5))
ax.bar(departments, responsibility_count)
ax.set_title("RACI Participation by Department")
ax.set_xlabel("Department")
ax.set_ylabel("Number of Key Responsibilities (R/A)")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

#-----------------------
# Stakeholder lists
stakeholders = [
    ("Project Manager (IT)", "High", "High"),
    ("IT Department Staff", "High", "Medium"),
    ("External Consultants", "Medium", "Medium"),
    ("Sales Department", "High", "High"),
    ("Design Department", "Medium", "Medium"),
    ("Financial Department", "High", "Medium"),
    ("Company Management (Sponsors)", "High", "Low"),
]

influence_levels = ["Low", "Medium", "High"]
interest_levels = ["Low", "Medium", "High"]

# 3x3 matris 
heatmap_matrix = np.zeros((len(influence_levels), len(interest_levels)), dtype=int)

# Influence / Interest strings
influence_index = {level: i for i, level in enumerate(influence_levels)}
interest_index = {level: j for j, level in enumerate(interest_levels)}

for name, influence, interest in stakeholders:
    i = influence_index[influence]
    j = interest_index[interest]
    heatmap_matrix[i, j] += 1

fig, ax = plt.subplots(figsize=(6, 5))
im = ax.imshow(heatmap_matrix)

# axises
ax.set_xticks(np.arange(len(interest_levels)))
ax.set_yticks(np.arange(len(influence_levels)))
ax.set_xticklabels(interest_levels)
ax.set_yticklabels(influence_levels)

ax.set_xlabel("Interest")
ax.set_ylabel("Influence")
ax.set_title("Stakeholder Risk Distribution (Influence vs Interest)")


for i in range(len(influence_levels)):
    for j in range(len(interest_levels)):
        value = heatmap_matrix[i, j]
        ax.text(j, i, str(value), ha="center", va="center")

fig.colorbar(im, ax=ax, shrink=0.8)
plt.tight_layout()
plt.show()
